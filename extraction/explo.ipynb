# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Data_Science_Jobs.csv")
df = df[df["Role_Category"] == "Analytics & BI"]
df = df[["Skill1", "Skill1", "Skill2", "Skill3", "Skill4", "Skill5", "Skll6", "Skill7", "Skill8" ]]
df
# Out:
#                     Skill1                 Skill1               Skill2  \
# 0                IT Skills              IT Skills               Python
# 6                IT Skills              IT Skills               Python
# 7    Regression Algorithms  Regression Algorithms                  NLP
# 12               IT Skills              IT Skills         Data Science
# 15               IT Skills              IT Skills               Python
# ..                     ...                    ...                  ...
# 539           Data Science           Data Science                Excel
# 541           Data Science           Data Science                    R
# 547           Data Science           Data Science  Predictive Modeling
# 548           Data Science           Data Science  Predictive Modeling
# 564    Predictive Modeling    Predictive Modeling  Logistic Regression
#
#                Skill3                   Skill4               Skill5  \
# ...

# %%
count = 0
liste_skills = []
for _, row in df.iterrows():
    for item in row:
        count+=1
        if item not in liste_skills:
            liste_skills.append(item)

# %%
dict_skills = {item: 0 for item in liste_skills}

# %%
for _, row in df.iterrows():
    for item in row:
        dict_skills[item] += 1/1179*100

# %%
top_10 = dict(sorted(dict_skills.items(), key=lambda item: item[1], reverse=True)[:15])

# %%
top_10
# Out:
# {'Data Science': 168,
#  'IT Skills': 118,
#  'Machine Learning': 62,
#  'Python': 56,
#  nan: 48,
#  'Big Data': 30,
#  'Data Scientist': 29,
#  'Artificial Intelligence': 26,
#  'R': 25,
#  'Predictive Modeling': 21,
#  'Data Management': 20,
#  'Tableau': 19,
#  'NLP': 16,
#  'Cloud': 16,
#  'Java': 16}

# %%
count
# Out:
# 1179
